# %%
#곡선 그리기
import matplotlib.pyplot as plt

X = range(100)
Y = [value**2 for value in X]
#0~100 까지 제곱한것을 그림

plt.plot(X, Y)
plt.show()

# %%
import math

T = range(100)
X = [(2 * math.pi * t) / len(T) for t in T]
Y = [math.sin(value) for value in X]

plt.plot(X, Y)
plt.show()

# %%
import numpy as np
X = np.linspace(0, 2 * np.pi, 100)
Y = np.sin(X)

plt.plot(X, Y)
plt.show()

# %%
X = np.linspace(-3, 2, 200)
Y = X**2 - 2 * X + 1.

plt.plot(X, Y)
plt.show()

# %%
X = np.linspace(0, 2 * np.pi, 100)
Ya = np.sin(X)
Yb = np.cos(X)

plt.plot(X, Ya)
plt.plot(X, Yb)
plt.show()

# %%
def plot_slope(X, Y):
    Xs = X[1:] - X[:-1]
    Ys = Y[1:] - Y[:-1]
    plt.plot(X[1:], Ys / Xs)  # 렌더링 선언


X = np.linspace(-3, 3, 100)
Y = np.exp(-X**2)

plt.plot(X, Y)  # 렌더링 선언
plot_slope(X, Y)
plt.show()  # 렌더링 실행

# %%
X, Y = [], []
for line in open('my_data.txt', 'r'):
    values = [float(s) for s in line.split()]
    X.append(values[0])
    Y.append(values[1])

plt.plot(X, Y)
plt.show()

# %%
with open('my_data.txt', 'r') as f:
    X, Y = zip(*[[float(s) for s in line.split()] for line in f])

plt.plot(X, Y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-7385f8fd2a8a> in <module>()
#       1 with open('my_data.txt', 'r') as f:
# ----> 2     X, Y = zip(*[[float(s) for s in line.split()] for line in f])
#       3
#       4 plt.plot(X, Y)
#       5 plt.show()
#
# ValueError: too many values to unpack (expected 2)

# %%
data = np.loadtxt('my_data.txt')

plt.plot(data[:, 0], data[:, 1])
plt.show()

# %%
data = np.loadtxt('my_data.txt')
for column in data.T:  #column은 전치행렬
    plt.plot(data[:, 0], column)

plt.show()

# %%
#점그리기

data = np.random.rand(1024, 2)

plt.scatter(data[:, 0], data[:, 1])  #x, y좌표를 입력 파라미터로 취함
plt.show()

# %%
#막대 차트 그리기

data = [5., 25., 50., 20.]

plt.bar(range(len(data)), data)
plt.show()

# %%
plt.bar(range(len(data)), data, width=1.)
plt.show()

# %%
plt.barh(range(len(data)), data)
plt.show()

# %%
data = [[5., 25., 50., 20.], [4., 23., 41., 17.], [6., 22., 52., 19]]

X = np.arange(4)
plt.bar(X + 0.00, data[0], color='b', width=0.25)
plt.bar(X + 0.25, data[1], color='g', width=0.25)
plt.bar(X + 0.50, data[2], color='r', width=0.25)

plt.show()

# %%
A = [5., 30., 45., 22.]
B = [5., 25., 50., 20.]

X = range(4)

plt.bar(X, A, color='b')
plt.bar(X, B, color='r', bottom=A)
plt.show()

# %%
A = np.array([5., 30., 45., 22.])
B = np.array([5., 25., 50., 20.])
C = np.array([1., 2., 1., 1.])
X = np.arange(4)

plt.bar(X, A, color='b')
plt.bar(X, B, color='g', bottom=A)
plt.bar(X, C, color='r', bottom=A + B)
# Out:
# <BarContainer object of 4 artists>

# %%
data = np.array([[5., 30., 45., 22.], [5., 25., 50., 20.], [1., 2., 1., 1.]])

color_list = ['b', 'g', 'r']
X = np.arange(data.shape[1])
for i in range(data.shape[0]):
    plt.bar(
        X,
        data[i],
        bottom=np.sum(data[:i], axis=0),
        color=color_list[i % len(color_list)])

plt.show()

# %%
#양방향 막대 차트 그리기
#왼쪽에 남성 인구, 오른쪽에 여성 인구

# %%
women_pop = np.array([5., 30., 45., 22.])
men_pop = np.array([5., 25., 50., 20.])
X = np.arange(4)

plt.barh(X, women_pop, color='r')
plt.barh(X, -men_pop, color='b')
plt.show()

# %%
#원형 차트그리기 pyplot.pe

# %%
data = [5, 25, 40, 20]

plt.pie(data)
plt.show()

# %%
# 리스트를 입력으로 취함. 상대적인 비율로 계산

# %%
#히스토그램 그리기
#확률 분포의 그래픽 표현

# %%
#정규분포 100개의값, 20개의 빈이 있는 히스토그램

X=np.random.randn(1000)

plt.hist(X, bins = 20)
plt.show()

# %%
#상자 그림 그리기 - 중간값, 사분위수, 최대값, 최소값

# %%
data = np.random.randn(100)
plt.boxplot(data)
plt.show()

# %%
data = np.random.randn(100, 5)

plt.boxplot(data)
plt.show()

# %%
#삼각화 그리기

# %%
data = np.random.rand(100, 2)

import matplotlib.tri as tri
triangles = tri.Triangulation(data[:,0], data[:,1])

plt.triplot(triangles)

# %%
data
# Out:
# array([[0.37367134, 0.06838478],
#        [0.16806726, 0.98180961],
#        [0.08526751, 0.67150482],
#        [0.9931934 , 0.89375806],
#        [0.68987063, 0.55437806],
#        [0.38580743, 0.01149414],
#        [0.63814051, 0.27698579],
#        [0.38021125, 0.14514632],
#        [0.03328509, 0.50690963],
#        [0.12392334, 0.45701588],
#        [0.55514009, 0.81348626],
#        [0.11898195, 0.91783955],
#        [0.91904081, 0.27138668],
#        [0.42028631, 0.77302904],
#        [0.89148184, 0.06386968],
#        [0.87744304, 0.24371792],
#        [0.4009889 , 0.38622971],
#        [0.34339504, 0.93423104],
#        [0.70494326, 0.83327558],
#        [0.18407284, 0.61084641],
#        [0.02548415, 0.74379072],
#        [0.10767245, 0.19695419],
#        [0.44438796, 0.03083997],
#        [0.88712188, 0.20427249],
#        [0.7539835 , 0.08952582],
#        [0.20047778, 0.42469325],
#        [0.56670449, 0.21763684],
#        [0.29819358, 0.17919413],
# ...
